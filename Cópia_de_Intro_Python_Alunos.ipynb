# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuelcop3/api-para-cotacao-de-moedas/blob/main/C%C3%B3pia_de_Intro_Python_Alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Links interesantes:
#
# - [Diferenças e Semelhanças entre JS e Python](https://www.freecodecamp.org/portuguese/news/python-x-javascript-qual-a-diferenca-entre-essas-duas-linguagens-de-programacao-tao-populares/#:~:text=Tanto%20Python%20quanto%20JavaScript%20suportam,elementos%20desse%20paradigma%20de%20programa%C3%A7%C3%A3o.)
# - [Markdown sintaxe](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# # Variaveis númericas e string

# %% [markdown]
# # Entrada e Saída

# %% [markdown]
# # Operadores Aritiméticos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Operadores Relacionais e Lógicos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Estruturas de Controle
#
# Bloco de código é definido pela identação

# %% [markdown]
# # Coleções

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Listas

# %% [markdown]
# ## Métodos de uma lista

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Fatiamento

# %% [markdown]
# ### Listas alinhadas

# %% [markdown]
# ## Dicionários
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tuplas
#
# https://www.treinaweb.com.br/blog/manipulando-tuplas-no-python

# %%
# Exercite depois aqui! :)

# %% [markdown]
# ## Conjuntos
#
# https://pythonhelp.wordpress.com/2013/06/18/conjuntos-em-python/
#
# https://algoritmosempython.com.br/cursos/programacao-python/conjuntos/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Exercite aqui!

# %% [markdown]
# ## +Strings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### String Format

# %% [markdown]
# # Estrutura de Repetição: For

# %% [markdown]
# # Funções

# %% [markdown]
# # Importando bibliotecas

# %% [markdown]
# # Instalando novas bibliotecas no colab

# %%
# !pip
